# %% [markdown]
# # Basic Plotting

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# pyplot is a submodule within matplotlib that provides a MATLAB-like interface for making plots

# %% [markdown]
# # MATPLOTLIB: mainly used for 2D plotting

# %%
# Create two lists
x = [10, 20, 30, 40]
y = [0, 15, 10, 25]

# %%
# 2D line plot
plt.plot(x,y)
# plt.plot(x,y); # suppress the comment

# %% [markdown]
# # Seaborn

# %% [markdown]
# 1. Seaborn updates Matplotlib's rc (run command) parameters to improve the aesthetic quality of image
# 2. Seaborn is a wrapper for Matplotlib

# %%
sns.set_theme() # Alias for set_theme()

# %%
plt.plot(x,y) # update the rc parameters of pyplot

# %%
sns.set_style('whitegrid');

# %%
plt.plot(x,y);

# %%
sns.set_style('white')
plt.plot(x,y)
plt.xlabel('Time')
plt.ylabel('Price')
# plt.ylabel('Price', fontsize=18) # change font size of xlabel
plt.title('Price vs. Time')
# Out:
# Text(0.5, 1.0, 'Price vs. Time')

# %% [markdown]
# # Seaborn with Pandas

# %%
#Check available dataset in seaborn
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
#Let's load the dataset called tips
df = sns.load_dataset('tips')
print(df.shape) # attribute
df.head(10)
# Out:
# (244, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# # Kernel Density Estimation (KDE) plot

# %% [markdown]
# KDE plot is a Kernel Density Estimation Plot which depicts the probability density function of the continuous or non-parametric data variables i.e. we can plot for the univariate or multiple variables altogether.

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
#Let's use the 'mpg' dataset
cars = sns.load_dataset('mpg')
print(cars.shape)
cars.head()
# Out:
# (398, 9)
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
#Let's make the KDE plot for horsepower
sns.kdeplot(x = 'horsepower', data = cars) # Plot univariate or bivariate distributions using kernel density estimation.
# not a normal distribution
# Out:
# <Axes: xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(x = 'horsepower', data = cars, shade = True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_31908\2546385702.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x = 'horsepower', data = cars, shade = True)
# <Axes: xlabel='horsepower', ylabel='Density'>

# %%
plt.figure(figsize = (15,15)) # change the figure size
sns.kdeplot(x = 'horsepower', data = cars, cumulative = True) # convert to a S-shaped CDF graph
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[32], line 2
#       1 plt.figure(figsize = (15,15)) # change the figure size
# ----> 2 sns.kdeplot(x = 'horsepower', data = cars, cumulative = True) # convert to a S-shaped CDF graph
#
# File E:\AI Engineering\Data_Cleanup\.venv\Lib\site-packages\seaborn\distributions.py:1701, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1697 if p.univariate:
#    1699     plot_kws = kwargs.copy()
# -> 1701     p.plot_univariate_density(
#    1702         multiple=multiple,
#    1703         common_norm=common_norm,
#    1704         common_grid=common_grid,
#    1705         fill=fill,
#    1706         color=color,
# ...

# %%
sns.kdeplot(x = 'horsepower', data = cars, vertical = True) # reverse the axis

# %%
sns.kdeplot(x = 'horsepower', data = cars, shade = True, hue = 'origin') # hue used for categorical variables

# %%
sns.kdeplot(x = 'horsepower', data = cars, color = 'blue', shade = True)

# %% [markdown]
# # Histogram

# %%
print(sns.get_dataset_names())

# %%
penguins = sns.load_dataset('penguins')

# %%
print(penguins.shape)
penguins.head()

# %%
penguins.dropna(inplace = True) # drop missing values
penguins.shape

# %%
penguins['species'].unique() # prints unique values of species column

# %%
sns.set_style('darkgrid')
sns.histplot(x = 'species', data = penguins);

# %%
sns.histplot(y = 'bill_length_mm', data = penguins);

# %%
sns.histplot(x = 'bill_length_mm', kde = True, data = penguins); # plot KDE and histrogram

# %%
sns.histplot(x = 'bill_length_mm', bins = 20, data = penguins);

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, binwidth = 10);

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, binwidth = 10, binrange = (30, 60));

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, stat = 'count');

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, stat = 'density'); # changes the y-axis

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, stat = 'probability');

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, stat = 'probability', fill = False);

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, stat = 'probability', fill = False, element = 'step');

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, stat = 'probability', fill = False, element = 'step', cumulative = True);

# %% [markdown]
# # Histogram with categorical variables

# %%
penguins.head()

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, hue = 'species');

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, hue = 'species', element = 'step');

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, hue = 'species', multiple = 'layer');

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, hue = 'species', multiple = 'stack');

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, hue = 'species', multiple = 'fill');

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, hue = 'species');

# %%
penguins.head()

# %%
sns.histplot(x = 'species', data = penguins, hue = 'sex', multiple = 'dodge');

# %% [markdown]
# # Boxplot

# %%
cars = sns.load_dataset('mpg').dropna()
cars.shape

# %%
cars.head()

# %%
sns.set_style('whitegrid')

# %%
cars['cylinders'].value_counts()

# %%
cars = cars[cars['cylinders'].isin([4,6,8])]

# %%
print(cars.shape)
cars['cylinders'].value_counts()

# %%
sns.boxplot(x = cars['mpg']);

# %%
#Summary statistics 
cars['mpg'].describe()

# %%
cars.head()

# %%
sns.boxplot(x= 'origin', y = 'mpg', data = cars)

# %%
# implementation of the Tukey's algorithm
# values that look different from the other values in the data
# Box plots are a visual method to identify outliers
def findOutliers(dataset):
    outliers = []
    Q2 = dataset.median()
    Q1 = dataset.describe()[4]
    Q3 = dataset.describe()[6]
    
    # Q1 = dataset.quantile(0.25)
    # Q3 = dataset.quantile(0.75)
    
    # 
    
    IQR = Q3 - Q1
    lf = Q1 - 1.5*IQR # lf = lower fence
    uf = Q3 + 1.5*IQR # Uf = Upper fence
    for x in dataset:
        if x < lf or x > uf:
            outliers.append(x)
    return outliers

# %%
cars.describe()

# %%
cars['mpg'].quantile(0.25)

# %%
findOutliers(cars['mpg'])

# %%
sns.boxplot(x = 'horsepower', data = cars)

# %%
findOutliers(cars['horsepower'])

# %%
cars.head()

# %%
sns.boxplot(x = 'origin', y = 'mpg', hue = 'cylinders', data = cars);

# %%
sns.boxplot(y = 'mpg', x = 'origin', data = cars)

# %%
sns.boxplot(x = 'mpg', y = 'origin', data = cars);

# %%
sns.boxplot(x = 'mpg', y = 'origin', data = cars, order = ['japan', 'europe', 'usa']);

# %% [markdown]
# # Swarmplot: Draw a categorical scatterplot

# %%
myData = [1,1,1,1,1, 2, 2, 2, 3, 4, 4, 4, 4, 4, 5, 5]
sns.swarmplot(x = myData)

# %%
sns.swarmplot(x = 'horsepower', data = cars);

# %%
#plt.figure(figsize = (7,7))
sns.swarmplot(x = 'origin',y = 'horsepower', data = cars);

# %%
sns.stripplot(x = 'origin',y = 'horsepower', data = cars);

# %% [markdown]
# # Both swarmplot and stripplot are categorical scatter plots used for visualizing data distributions, but they differ in how they handle overlapping points.
# Stipplot: Points may overlap, making it harder to see density.
# Swarmplot: Points are spread out horizontally, making density easier to see.

# %%
sns.swarmplot(x = 'origin',y = 'horsepower', hue = 'cylinders', data = cars);

# %%
#Note: Swarmplot does not scale very well when it comes to large amount of data
sns.swarmplot(x = 'origin',y = 'horsepower', hue = 'cylinders', dodge = True, data = cars);

# %% [markdown]
# # Swarmplot overlay with Boxplot

# %%
usa = cars[cars['origin'] == 'usa']

# %%
sns.boxplot(x = usa.cylinders, y = usa.horsepower)

# %%
sns.boxplot(x = usa.cylinders, y = usa.horsepower)
sns.swarmplot(x = usa.cylinders, y = usa.horsepower)

# %%
sns.boxplot(x = usa.cylinders, y = usa.horsepower)
sns.swarmplot(x = usa.cylinders, y = usa.horsepower, color = 'black');

# %%
sns.boxplot(x = usa.cylinders, y = usa.horsepower)
sns.swarmplot(x = usa.cylinders, y = usa.horsepower, color = 'black', alpha = 0.5);

# %%
sns.boxplot(x = usa.cylinders, y = usa.horsepower)
sns.stripplot(x = usa.cylinders, y = usa.horsepower, color = 'black', alpha = 0.5);

# %%
# Sample data
x = [10, 20, 30, 40, 50]  # X-axis values
y = [5, 15, 25, 35, 45]   # Y-axis values
size = [100, 200, 300, 400, 500]  # Bubble sizes

# Create bubble plot
plt.scatter(x, y, s=size, alpha=1, c='blue', edgecolors='black')

# alpha sets the transparency level of a plot element

# Labels and title
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Bubble Plot Example")

plt.show()
